# %%
# AWS INSTANCE에서 데이터 가져오기
import mysql.connector

yespa_db = mysql.connector.connect(
    host = 'database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port = 3306,
    user = 'eda_team',
    database = 'eda_project',
    password = '123456'
)

cur = yespa_db.cursor(buffered=True, dictionary=True)

cur.execute('SELECT * FROM GIHU_metro_coor')
result = cur.fetchall()

for data in result:
    print(data)
    
yespa_db.close()
# Out:
# {'역명': '창동', '호선': '1호선', '위도': 37.653181, '경도': 127.047663}
# {'역명': '월계', '호선': '1호선', '위도': 37.633114, '경도': 127.058835}
# {'역명': '외대앞', '호선': '1호선', '위도': 37.596157, '경도': 127.063572}
# {'역명': '대방', '호선': '1호선', '위도': 37.513392, '경도': 126.926407}
# {'역명': '신길', '호선': '1호선', '위도': 37.517018, '경도': 126.917743}
# {'역명': '구일', '호선': '1호선', '위도': 37.496273, '경도': 126.869599}
# {'역명': '온수', '호선': '1호선', '위도': 37.492267, '경도': 126.823399}
# {'역명': '소요산', '호선': '1호선', '위도': 37.5653, '경도': 127.0339}
# {'역명': '도봉산', '호선': '1호선', '위도': 37.689603, '경도': 127.046347}
# {'역명': '방학', '호선': '1호선', '위도': 37.66796, '경도': 127.04456}
# {'역명': '녹천', '호선': '1호선', '위도': 37.644599, '경도': 127.051406}
# {'역명': '석계', '호선': '1호선', '위도': 37.615206, '경도': 127.065594}
# {'역명': '신이문', '호선': '1호선', '위도': 37.60274474, '경도': 127.067556}
# {'역명': '회기', '호선': '1호선', '위도': 37.589802, '경도': 127.057936}
# {'역명': '남영', '호선': '1호선', '위도': 37.540597, '경도': 126.971171}
# ...

# %%
from haversine import haversine
distance = haversine(, unit='m')

# harversine((출발 위도,출발 경도) ,(도착위도, 도착,경도) , unit=m(mt단위) (키로미터로도 변경가능함)

# %%
url용인= 'https://www.google.com/maps/place/%EA%B3%A0%EC%96%91%EC%8B%9C%EC%B2%AD/data=!4m14!1m7!3m6!1s0x357c908f18da12d1:0x322052cfcbd9c325!2z6rOg7JaR7Iuc7LKt!8m2!3d37.6582159!4d126.8320138!16s%2Fg%2F1w0p3kms!3m5!1s0x357c908f18da12d1:0x322052cfcbd9c325!8m2!3d37.6582159!4d126.8320138!16s%2Fg%2F1w0p3kms?entry=ttu'
url용인= 'https://www.google.com/maps/place/%EC%9A%A9%EC%9D%B8%EC%8B%9C%EC%B2%AD/data=!4m10!1m2!2m1!1z7Jqp7J247Iuc7LKt!3m6!1s0x357b51c8e1629001:0xbce2a0332ff3c470!8m2!3d37.240608!4d127.1772935!15sCgzsmqnsnbjsi5zssq2SAQljaXR5X2hhbGzgAQA!16s%2Fg%2F1tczsvy_?entry=ttu'

# %%
coor, latitude, longitude = [], [], []

for url in current_url:
    coor_part = url.split('!3d')[1]
    lat_part = coor_part.split('!4d')[0]
    lon_part = coor_part.split('!4d')[1].split('!')[0]
    
    latitude.append(lat_part)
    longitude.append(lon_part)

latitude, longitude

# %%
[[고양시청, 1750],[용인시청 , 2400],[부천시청, 1700]]
