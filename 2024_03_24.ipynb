# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from incheon")
result = cursor.fetchall()

df_incheon_bus = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from traffic_seoul")
result = cursor.fetchall()

df_traffic = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from incheon")
result = cursor.fetchall()

df_incheon_bus = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from gyeonggi_bus")
result = cursor.fetchall()

df_gyeonggi_bus = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from seoul_bus_station_coor")
result = cursor.fetchall()

df_seoul_bus_station_coor = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from gyeonggi_bus_ver2")
result = cursor.fetchall()

df_gyeonggi_bus2 = pd.DataFrame(result)

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host='database-1.c3ieyo8m4v9o.ap-northeast-2.rds.amazonaws.com',
    port=3306,
    user='eda_team',
    password='123456',
    database='eda_project'
)
cur = conn.cursor()
cursor = conn.cursor(dictionary = True)
# cursor = conn.cursor(dictionary=True)

cursor.execute("select * from gyeonggi_bus_ver3")
result = cursor.fetchall()

df_gyeonggi_bus3 = pd.DataFrame(result)

# %%
conn.close()

# %%
import pandas as pd

df_seoul_bus = pd.read_csv('../data/서울시 버스노선별 정류장별 시간대별 승하차 인원 정보.csv', encoding='cp949', dtype=str)

# %%
df_incheon_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19440 entries, 0 to 19439
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        19440 non-null  int64
#  1   정류소명      19440 non-null  object
#  2   정류소아이디    19440 non-null  float64
#  3   총승차건수     19440 non-null  float64
#  4   총하차건수     19440 non-null  float64
#  5   승차건수(카드)  19440 non-null  float64
#  6   하차건수(카드)  19440 non-null  float64
#  7   승차건수(현금)  19440 non-null  float64
#  8   일평균승하차건수  19440 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df_gyeonggi_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25204 entries, 0 to 25203
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    25204 non-null  int64
#  1   노선번호    25204 non-null  object
#  2   00~01시  25204 non-null  int64
#  3   01~02시  25204 non-null  int64
#  4   02~03시  25204 non-null  int64
#  5   03~04시  25204 non-null  int64
#  6   04~05시  25204 non-null  int64
#  7   05~06시  25204 non-null  int64
#  8   06~07시  25204 non-null  int64
#  9   07~08시  25204 non-null  int64
#  10  08~09시  25204 non-null  int64
#  11  09~10시  25204 non-null  int64
#  12  10~11시  25204 non-null  int64
#  13  11~12시  25204 non-null  int64
#  14  12~13시  25204 non-null  int64
#  15  13~14시  25204 non-null  int64
#  16  14~15시  25204 non-null  int64
#  17  15~16시  25204 non-null  int64
#  18  16~17시  25204 non-null  int64
#  19  17~18시  25204 non-null  int64
#  20  18~19시  25204 non-null  int64
# ...

# %%
df_seoul_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42370 entries, 0 to 42369
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사용년월        42370 non-null  object
#  1   노선번호        42370 non-null  object
#  2   노선명         42370 non-null  object
#  3   표준버스정류장ID   42370 non-null  object
#  4   버스정류장ARS번호  42370 non-null  object
#  5   역명          42370 non-null  object
#  6   00시승차총승객수   42370 non-null  object
#  7   00시하차총승객수   42370 non-null  object
#  8   1시승차총승객수    42370 non-null  object
#  9   1시하차총승객수    42370 non-null  object
#  10  2시승차총승객수    42370 non-null  object
#  11  2시하차총승객수    42370 non-null  object
#  12  3시승차총승객수    42370 non-null  object
#  13  3시하차총승객수    42370 non-null  object
#  14  4시승차총승객수    42370 non-null  object
#  15  4시하차총승객수    42370 non-null  object
#  16  5시승차총승객수    42370 non-null  object
#  17  5시하차총승객수    42370 non-null  object
#  18  6시승차총승객수    42370 non-null  object
# ...

# %% [markdown]
# --------
# # 서울 버스 분석

# %%
df_seoul_bus.columns
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
#        '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '교통수단타입코드',
#        '교통수단타입명', '등록일자'],
#       dtype='object')

# %%
df_seoul_bus.head(2)
# Out:
#      사용년월 노선번호                    노선명  표준버스정류장ID 버스정류장ARS번호              역명  \
# 0  202402  741      741번(진관차고지~헌인릉입구)  100000001      01001  종로2가사거리(00075)
# 1  202402  N37  N37번(송파공영차고지~진관공영차고지)  100000001      01001  종로2가사거리(00032)
#
#   00시승차총승객수 00시하차총승객수 1시승차총승객수 1시하차총승객수  ... 20시하차총승객수 21시승차총승객수 21시하차총승객수  \
# 0       113       135       87      117  ...       231       240       156
# 1         9        17      160      177  ...         0         0         0
#
#   22시승차총승객수 22시하차총승객수 23시승차총승객수 23시하차총승객수 교통수단타입코드 교통수단타입명      등록일자
# 0       209       135       197       111      010  서울간선버스  20240303
# 1         0         0         0         0      051  서울심야버스  20240303
#
# [2 rows x 57 columns]

# %%
df_seoul_bus['교통수단타입명'].value_counts()
# Out:
# 교통수단타입명
# 서울지선버스    16344
# 서울간선버스    13258
# 서울마을버스     7570
# 서울심야버스     4328
# 서울광역버스      830
# 서울순환버스       40
# Name: count, dtype: int64

# %% [markdown]
# 간선버스 : 주요 간선도로 중심, 권역 간을 연결하는 역할 (줄기)
#
# 지선버스 : 간선버스를 보조하는 역할 (나뭇가지)
#
#
# 간선 + 지선 = 시내버스

# %%
df_seoul_bus['사용년월'].value_counts()
# Out:
# 사용년월
# 202402    42370
# Name: count, dtype: int64

# %%
df_seoul_bus['노선명'].value_counts()
# Out:
# 노선명
# N62번(면목동차고지~양천공영차고지)     275
# N26번(중랑공영차고지~강서공영차고지)    224
# N62번(양천공영차고지~면목동차고지)     189
# N61번(상계동차고지~양천공영차고지)     188
# N61번(양천공영차고지~상계동차고지)     188
#                         ...
# 서울06(강남역~광주시능평동)           9
# 서울03(홍대입구역~파주시운정지구)        7
# 동대문01(회기역~경희대)             6
# 서울02(김포시풍무동~김포공항역)         6
# 서울05(양주시옥정신도시~도봉산역)        6
# Name: count, Length: 654, dtype: int64

# %% [markdown]
# 서울시 버스 노선 654개
#
# 같은 노선명은 제 각각 역명이 다르다.

# %%
len(df_seoul_bus['노선명'].value_counts())
# Out:
# 654

# %%
df_seoul_bus['노선명'].max()
# Out:
# '중랑02(진로아파트~한신아파트)'

# %%
df_seoul_bus[df_seoul_bus['노선명'] == '서울05(양주시옥정신도시~도봉산역)']
# Out:
#          사용년월  노선번호                  노선명  표준버스정류장ID 버스정류장ARS번호  \
# 12580  202402  서울05  서울05(양주시옥정신도시~도봉산역)  109000405      10339
# 42093  202402  서울05  서울05(양주시옥정신도시~도봉산역)  235000078      68131
# 42094  202402  서울05  서울05(양주시옥정신도시~도봉산역)  235000079      68140
# 42095  202402  서울05  서울05(양주시옥정신도시~도봉산역)  235000083      68136
# 42121  202402  서울05  서울05(양주시옥정신도시~도봉산역)  235000392      68142
# 42125  202402  서울05  서울05(양주시옥정신도시~도봉산역)  235001491      68141
#
#                                 역명 00시승차총승객수 00시하차총승객수 1시승차총승객수 1시하차총승객수  ...  \
# 12580            도봉산역광역환승센터(00006)         0         0        0        0  ...
# 42093             율정마을7.8단지(00001)         0         0        0        0  ...
# 42094     옥정상가주택.대방노블랜드12단지(00003)         0         0        0        0  ...
# 42095   제일풍경채레이크시티.율정마을13단지(00002)         0         0        0        0  ...
# 42121              덕현초교.덕고개(00005)         0         0        0        0  ...
# ...

# %%
df_seoul_bus[df_seoul_bus['노선명'] == '중랑02(진로아파트~한신아파트)']
# Out:
#         사용년월  노선번호                노선명  표준버스정류장ID 버스정류장ARS번호  \
# 7374  202402  중랑02  중랑02(진로아파트~한신아파트)  106000055      07149
# 7571  202402  중랑02  중랑02(진로아파트~한신아파트)  106000101      07195
# 7690  202402  중랑02  중랑02(진로아파트~한신아파트)  106000127      07222
# 7701  202402  중랑02  중랑02(진로아파트~한신아파트)  106000129      07224
# 7704  202402  중랑02  중랑02(진로아파트~한신아파트)  106000130      07225
# 7728  202402  중랑02  중랑02(진로아파트~한신아파트)  106000135      07230
# 7737  202402  중랑02  중랑02(진로아파트~한신아파트)  106000136      07231
# 8523  202402  중랑02  중랑02(진로아파트~한신아파트)  106000440      07436
# 8676  202402  중랑02  중랑02(진로아파트~한신아파트)  106900002      07527
# 8677  202402  중랑02  중랑02(진로아파트~한신아파트)  106900003      07525
# 8681  202402  중랑02  중랑02(진로아파트~한신아파트)  106900008      07519
# 8682  202402  중랑02  중랑02(진로아파트~한신아파트)  106900009      07517
# 8683  202402  중랑02  중랑02(진로아파트~한신아파트)  106900010      07515
# 8684  202402  중랑02  중랑02(진로아파트~한신아파트)  106900012      07512
# 8685  202402  중랑02  중랑02(진로아파트~한신아파트)  106900013      07510
# ...

# %%
df_seoul_bus_station_coor
# Out:
#                 name   lagtitude  longitude
# 0            종로2가사거리  126.987752  37.569808
# 1        창경궁.서울대학교병원  126.996522  37.579433
# 2          명륜3가.성대입구  126.998251  37.582581
# 3           종로2가.삼일교  126.987613  37.568579
# 4      혜화동로터리.여운형활동터  127.001744  37.586243
# ...              ...         ...        ...
# 11285          우성아파트  127.139339  37.550386
# 11286          우성아파트  127.140046  37.550643
# 11287           조일약국  127.123596  37.533630
# 11288           성내시장  127.125497  37.536155
# 11289    천호우체국.로데오거리  127.127337  37.540343
#
# [11290 rows x 3 columns]

# %% [markdown]
# 서울시 노선별 시간대 상관없이 많이 사용한 승하차한 노선

# %%
df_seoul_bus.columns
# Out:
# Index(['사용년월', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역명', '00시승차총승객수',
#        '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', '3시승차총승객수',
#        '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', '6시승차총승객수',
#        '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', '9시승차총승객수',
#        '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
#        '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수',
#        '14시하차총승객수', '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수',
#        '17시승차총승객수', '17시하차총승객수', '18시승차총승객수', '18시하차총승객수', '19시승차총승객수',
#        '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', '21시승차총승객수', '21시하차총승객수',
#        '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수', '교통수단타입코드',
#        '교통수단타입명', '등록일자'],
#       dtype='object')

# %%
# 시간대별 승차 및 하차 인원 컬럼 선택
time_columns = ['00시승차총승객수', '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수', '2시하차총승객수', 
                '3시승차총승객수', '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수', '5시하차총승객수', 
                '6시승차총승객수', '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수', '8시하차총승객수', 
                '9시승차총승객수', '9시하차총승객수', '10시승차총승객수', '10시하차총승객수', '11시승차총승객수', '11시하차총승객수',
                '12시승차총승객수', '12시하차총승객수', '13시승차총승객수', '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', 
                '15시승차총승객수', '15시하차총승객수', '16시승차총승객수', '16시하차총승객수', '17시승차총승객수', '17시하차총승객수', 
                '18시승차총승객수', '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수', '20시하차총승객수', 
                '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수', '23시승차총승객수', '23시하차총승객수']

# 시간대별 승차 및 하차 인원 합산
df_seoul_bus['총승차인원'] = df_seoul_bus[time_columns[::2]].astype(float).sum(axis=1)
df_seoul_bus['총하차인원'] = df_seoul_bus[time_columns[1::2]].astype(float).sum(axis=1)
# Out:
# 가장 활발한 노선: 143

# %% [markdown]
# 2024년 2월 승하차 인원이 가장 많은 노선은 143번 노선이다
#
# 160
# 272
# 271
# 130

# %%
df_seoul_bus.groupby('노선번호')[['총승차인원', '총하차인원']].sum().sort_values('총승차인원', ascending = False)
# Out:
#          총승차인원     총하차인원
# 노선번호
# 143   939873.0  906542.0
# 160   812622.0  794204.0
# 272   801894.0  783778.0
# 271   769881.0  751913.0
# 130   743265.0  730642.0
# ...        ...       ...
# 서울03    1450.0    1446.0
# 서울01    1425.0    1420.0
# 서울05    1183.0    1183.0
# 서울06     758.0     757.0
# 8777     303.0     294.0
#
# [636 rows x 2 columns]

# %% [markdown]
# 인덱스 31517번에서 가장 많이 타고
# 인덱스 31553번에서 가장 많이 하차하는 것을 알 수 있다.
#
# 또한 인덱스 1846도 활발한 것을 확인할 수 있음
#
# 31517, 31553 = 고속터미널
#
# 1846 = 롯데백화점 (2호선 을지로입구역)

# %%
df_seoul_bus[df_seoul_bus['노선번호'] == '143'][['총승차인원', '총하차인원']].sort_values('총승차인원', ascending = False)
# Out:
#          총승차인원    총하차인원
# 31517  48413.0  21516.0
# 1846   29475.0  23612.0
# 31553  29300.0  49998.0
# 34998  18681.0   6241.0
# 9052   18388.0   5962.0
# ...        ...      ...
# 34596    371.0   5116.0
# 9395     351.0   2723.0
# 34609    214.0   4924.0
# 9379      63.0  12342.0
# 10018     23.0   7811.0
#
# [114 rows x 2 columns]

# %%
df_seoul_bus[df_seoul_bus['노선번호'] == '160'][['총승차인원', '총하차인원']].sort_values('총승차인원', ascending = False)
# Out:
#          총승차인원    총하차인원
# 26298  27626.0  11198.0
# 26286  21610.0   7635.0
# 18078  20613.0  12756.0
# 23724  16967.0   9654.0
# 26312  16957.0  29196.0
# ...        ...      ...
# 467      731.0   2413.0
# 11786    643.0   7040.0
# 24331     62.0  14243.0
# 11768     27.0   6321.0
# 12590      5.0   3370.0
#
# [119 rows x 2 columns]

# %%
df_seoul_bus.loc[26312]
# Out:
# 사용년월                  202402
# 노선번호                     160
# 노선명            160번(도봉산~온수동)
# 표준버스정류장ID          118000008
# 버스정류장ARS번호             19008
# 역명            여의도환승센터(00041)
# 00시승차총승객수                  2
# 00시하차총승객수                  4
# 1시승차총승객수                   0
# 1시하차총승객수                   0
# 2시승차총승객수                   0
# 2시하차총승객수                   0
# 3시승차총승객수                   0
# 3시하차총승객수                   0
# 4시승차총승객수                   0
# 4시하차총승객수                   0
# 5시승차총승객수                 159
# 5시하차총승객수                 511
# 6시승차총승객수                  72
# 6시하차총승객수                1166
# 7시승차총승객수                 189
# 7시하차총승객수                3833
# 8시승차총승객수                 334
# 8시하차총승객수                4723
# 9시승차총승객수                 225
# 9시하차총승객수                3269
# 10시승차총승객수                244
# 10시하차총승객수               1369
# 11시승차총승객수                606
# 11시하차총승객수               1395
# 12시승차총승객수                558
# 12시하차총승객수               1484
# ...

# %%
df_seoul_bus[df_seoul_bus['노선번호'] == '143'][['총승차인원', '총하차인원']].sort_values('총하차인원', ascending = False)
# Out:
#          총승차인원    총하차인원
# 31553  29300.0  49998.0
# 1846   29475.0  23612.0
# 31517  48413.0  21516.0
# 33653  10654.0  17169.0
# 34002   3514.0  17122.0
# ...        ...      ...
# 34624   8487.0   1302.0
# 34591   3819.0    928.0
# 34588   3036.0    814.0
# 9373   17266.0    166.0
# 42186  11965.0     71.0
#
# [114 rows x 2 columns]

# %%
df_seoul_bus[df_seoul_bus['총승차인원'] == 48413.0]
# Out:
#          사용년월 노선번호           노선명  표준버스정류장ID 버스정류장ARS번호            역명  \
# 31517  202402  143  143번(정릉~개포동)  121000019      22019  고속터미널(00083)
#
#       00시승차총승객수 00시하차총승객수 1시승차총승객수 1시하차총승객수  ... 21시하차총승객수 22시승차총승객수  \
# 31517       658       111        7        1  ...       903      2205
#
#       22시하차총승객수 23시승차총승객수 23시하차총승객수 교통수단타입코드 교통수단타입명      등록일자    총승차인원  \
# 31517       591      1303       311      010  서울간선버스  20240303  48413.0
#
#          총하차인원
# 31517  21516.0
#
# [1 rows x 59 columns]

# %%
df_seoul_bus[df_seoul_bus['총하차인원'] == 49998.0]
# Out:
#          사용년월 노선번호           노선명  표준버스정류장ID 버스정류장ARS번호            역명  \
# 31553  202402  143  143번(정릉~개포동)  121000020      22020  고속터미널(00028)
#
#       00시승차총승객수 00시하차총승객수 1시승차총승객수 1시하차총승객수  ... 21시하차총승객수 22시승차총승객수  \
# 31553         2         2        0        0  ...      1991      1604
#
#       22시하차총승객수 23시승차총승객수 23시하차총승객수 교통수단타입코드 교통수단타입명      등록일자    총승차인원  \
# 31553      1525       133        56      010  서울간선버스  20240303  29300.0
#
#          총하차인원
# 31553  49998.0
#
# [1 rows x 59 columns]

# %%
df_seoul_bus[df_seoul_bus['총승차인원'] == 29475.0]
# Out:
#         사용년월 노선번호           노선명  표준버스정류장ID 버스정류장ARS번호            역명 00시승차총승객수  \
# 1846  202402  143  143번(정릉~개포동)  101000041      02140  롯데백화점(00020)         0
#
#      00시하차총승객수 1시승차총승객수 1시하차총승객수  ... 21시하차총승객수 22시승차총승객수 22시하차총승객수 23시승차총승객수  \
# 1846         2        0        0  ...       630      1118       413         5
#
#      23시하차총승객수 교통수단타입코드 교통수단타입명      등록일자    총승차인원    총하차인원
# 1846         2      010  서울간선버스  20240303  29475.0  23612.0
#
# [1 rows x 59 columns]

# %% [markdown]
# 고속터미널과 롯데백화점이 압도적으로 많으므로 어떤 시간대에 많이 이동되는지 시간 분포도를 확인해보겠음

# %% [markdown]
# 고속터미널은 한 노선에 2번 들려
#
# 31553인덱스에서 먼저 출발한 뒤 돌아오는 31517인덱스를 가는 것으로 추정됨
#
# 근거 : 새벽 4시에 탑승객이 있다 => 첫차
#
#       자정시간에 탑승객이 있다 => 막차

# %%
df_seoul_bus.loc[31553]
# Out:
# 사용년월                202402
# 노선번호                   143
# 노선명           143번(정릉~개포동)
# 표준버스정류장ID        121000020
# 버스정류장ARS번호           22020
# 역명            고속터미널(00028)
# 00시승차총승객수                2
# 00시하차총승객수                2
# 1시승차총승객수                 0
# 1시하차총승객수                 0
# 2시승차총승객수                 0
# 2시하차총승객수                 0
# 3시승차총승객수                 0
# 3시하차총승객수                 0
# 4시승차총승객수               265
# 4시하차총승객수               368
# 5시승차총승객수               744
# 5시하차총승객수              1560
# 6시승차총승객수               696
# 6시하차총승객수              1398
# 7시승차총승객수              1005
# 7시하차총승객수              2714
# 8시승차총승객수              1402
# 8시하차총승객수              4355
# 9시승차총승객수              1283
# 9시하차총승객수              3423
# 10시승차총승객수             1075
# 10시하차총승객수             2362
# 11시승차총승객수             1263
# 11시하차총승객수             2584
# 12시승차총승객수             1756
# 12시하차총승객수             3167
# 13시승차총승객수             1675
# 13시하차총승객수             3109
# ...

# %%
df_seoul_bus.loc[31517]
# Out:
# 사용년월                202402
# 노선번호                   143
# 노선명           143번(정릉~개포동)
# 표준버스정류장ID        121000019
# 버스정류장ARS번호           22019
# 역명            고속터미널(00083)
# 00시승차총승객수              658
# 00시하차총승객수              111
# 1시승차총승객수                 7
# 1시하차총승객수                 1
# 2시승차총승객수                 2
# 2시하차총승객수                 0
# 3시승차총승객수                 0
# 3시하차총승객수                 0
# 4시승차총승객수                 0
# 4시하차총승객수                 0
# 5시승차총승객수                 1
# 5시하차총승객수                 1
# 6시승차총승객수               716
# 6시하차총승객수               700
# 7시승차총승객수              1681
# 7시하차총승객수              1344
# 8시승차총승객수              2279
# 8시하차총승객수              1391
# 9시승차총승객수              2080
# 9시하차총승객수              1336
# 10시승차총승객수             2387
# 10시하차총승객수             1225
# 11시승차총승객수             2718
# 11시하차총승객수             1221
# 12시승차총승객수             2786
# 12시하차총승객수             1327
# 13시승차총승객수             2878
# 13시하차총승객수             1349
# ...

# %% [markdown]
# 어디서 출발하는지는 정확히 모르지만 고속터미널역에서 가장 많이 유동인구가 많은 것을 확인할 수 있음
#
# 시각화

# %%
df_seoul_bus.loc[31553].iloc[7:-4:2]
# Out:
# 00시하차총승객수       2
# 1시하차총승객수        0
# 2시하차총승객수        0
# 3시하차총승객수        0
# 4시하차총승객수      368
# 5시하차총승객수     1560
# 6시하차총승객수     1398
# 7시하차총승객수     2714
# 8시하차총승객수     4355
# 9시하차총승객수     3423
# 10시하차총승객수    2362
# 11시하차총승객수    2584
# 12시하차총승객수    3167
# 13시하차총승객수    3109
# 14시하차총승객수    3142
# 15시하차총승객수    3241
# 16시하차총승객수    3135
# 17시하차총승객수    3438
# 18시하차총승객수    3221
# 19시하차총승객수    3060
# 20시하차총승객수    2147
# 21시하차총승객수    1991
# 22시하차총승객수    1525
# 23시하차총승객수      56
# Name: 31553, dtype: object

# %% [markdown]
# 다른시간대보다 출 퇴근 시간대에 활발해지는 것을 알 수 있다.

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
# 31553 노선의 승차 인원 데이터 추출
data_31553 = df_seoul_bus.loc[31553].iloc[6:-5:2].astype(float)  # 승차인원만 추출

# 31517 노선의 승차 인원 데이터 추출
data_31517 = df_seoul_bus.loc[31517].iloc[6:-5:2].astype(float)  # 승차인원만 추출

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(data_31553, label='출발지 노선')
plt.plot(data_31517, label='도착지 노선')
plt.title('출발지 vs. 도착지 노선의 시간대별 승차 인원')
plt.xlabel('시간대')
plt.ylabel('승차 인원')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
# 31553 노선의 승차 인원 데이터 추출
data_31553h = df_seoul_bus.loc[31553].iloc[7:-4:2].astype(float)  # 승차인원만 추출

# 31517 노선의 승차 인원 데이터 추출
data_31517h = df_seoul_bus.loc[31517].iloc[7:-4:2].astype(float)  # 승차인원만 추출

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(data_31553h, label='출발지 노선')
plt.plot(data_31517h, label='도착지 노선')
plt.title('출발지 vs. 도착지 노선의 시간대별 하차 인원')
plt.xlabel('시간대')
plt.ylabel('승차 인원')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 정확히 어디에서 오는지는 모르지만 고속터미널을 포함해서
# 노선 160 여의도환승센터에도 사람들이 출퇴근 시간에 몰리는 것을 확인할 수 있다.

# %% [markdown]
# ---
# 경기

# %%
df_gyeonggi_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25204 entries, 0 to 25203
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    25204 non-null  int64
#  1   노선번호    25204 non-null  object
#  2   00~01시  25204 non-null  int64
#  3   01~02시  25204 non-null  int64
#  4   02~03시  25204 non-null  int64
#  5   03~04시  25204 non-null  int64
#  6   04~05시  25204 non-null  int64
#  7   05~06시  25204 non-null  int64
#  8   06~07시  25204 non-null  int64
#  9   07~08시  25204 non-null  int64
#  10  08~09시  25204 non-null  int64
#  11  09~10시  25204 non-null  int64
#  12  10~11시  25204 non-null  int64
#  13  11~12시  25204 non-null  int64
#  14  12~13시  25204 non-null  int64
#  15  13~14시  25204 non-null  int64
#  16  14~15시  25204 non-null  int64
#  17  15~16시  25204 non-null  int64
#  18  16~17시  25204 non-null  int64
#  19  17~18시  25204 non-null  int64
#  20  18~19시  25204 non-null  int64
# ...

# %% [markdown]
# 경기도는 승 하차 정보는 없고 두개 다 합산된 유동인구만 나와있다 근데 거기서 거기인 것 같아 큰 상관은 없어보임

# %%
df_gyeonggi_bus
# Out:
#          year        노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  \
# 0      202301           1    1069     103       5       0     109    1911
# 1      202301           2     553       3       0       0      64    1747
# 2      202301           3     924      13       0       0     159    1560
# 3      202301           4       0       0       0       0       0      13
# 4      202301           5     815      16       0       0     226    2202
# ...       ...         ...     ...     ...     ...     ...     ...     ...
# 25199  202402  공영2(삼존대광A)       0       0       0       0       0       0
# 25200  202402  공영2(송정대광A)       0       0       0       0       0       0
# 25201  202402  공영3(삼존.청원)       0       0       0       0       0       0
# 25202  202402  공영3(장문지화1)       0       0       0       0       0       0
# 25203  202402  공영4(돌내독지1)       0       0       0       0       0       0
#
#        06~07시  07~08시  ...  14~15시  15~16시  16~17시  17~18시  18~19시  19~20시  \
# ...

# %%
df_gyeonggi_bus['승하차'] = df_gyeonggi_bus.iloc[:, 2:].sum(axis=1)
df_gyeonggi_bus.head()
# Out:
#      year 노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  \
# 0  202301    1    1069     103       5       0     109    1911    5218
# 1  202301    2     553       3       0       0      64    1747    5136
# 2  202301    3     924      13       0       0     159    1560    4257
# 3  202301    4       0       0       0       0       0      13      88
# 4  202301    5     815      16       0       0     226    2202    5023
#
#    07~08시  ...  15~16시  16~17시  17~18시  18~19시  19~20시  20~21시  21~22시  \
# 0   10653  ...   11957   13297   13594   15537   11815    8727    8512
# 1   10443  ...   12933   13494   15100   15647   12240    8788    8491
# 2    8813  ...   11466   11652   12837   13957   10685    7890    7465
# 3     108  ...      79      50     154      76     127      89      44
# 4   10283  ...   11047   11944   13424   15626   11836    8346    7831
#
#    22~23시  23~24시     승하차
# 0    7273    3615  192142
# 1    6624    3064  197610
# 2    6931    3367  173101
# ...

# %%
df_gyeonggi_bus['노선번호'].value_counts()
# Out:
# 노선번호
# 1             14
# 22-21         14
# 24-11         14
# 23-94         14
# 23-93         14
#               ..
# 6002-1B        1
# 23-13          1
# 30-2(학통등교)     1
# 순환121A         1
# 고양똑버스01퇴       1
# Name: count, Length: 1932, dtype: int64

# %%
df_gyeonggi_bus[df_gyeonggi_bus['노선번호'] == '1']
# Out:
#          year 노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  \
# 0      202301    1    1069     103       5       0     109    1911    5218
# 1767   202302    1    1195      93       2       0      82    1884    5480
# 3522   202303    1    1087     126       9       0      88    1881    5671
# 5295   202304    1    1155     137       9       0     100    1873    5808
# 7074   202305    1    1067     131       4       0      98    2081    6172
# 8862   202306    1    1122     154       9       0     100    2014    6344
# 10650  202307    1    1342     163      12       0     114    2254    6261
# 12460  202308    1    1049     107       4       0     114    1998    5646
# 14270  202309    1    1027     119       8       0     119    2181    6702
# 16095  202310    1    1151      90       2       0     111    2170    6778
# 17924  202311    1    1058     133       6       0     124    2144    6244
# ...

# %%
df_gyeonggi_bus[df_gyeonggi_bus['year'] == 202301].groupby('노선번호')['승하차'].sum().sort_values(ascending = False)
# Out:
# 노선번호
# 10        230381
# 88        209532
# 2         197610
# 1         192142
# 5         182907
#            ...
# 930-2B         2
# 35-20          2
# 2-12           2
# 81-3           2
# 20-52          1
# Name: 승하차, Length: 1767, dtype: int64

# %%
df_gyeonggi_bus[df_gyeonggi_bus['노선번호'] == '10']
# Out:
#          year 노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  \
# 15     202301   10     898      21       0       0     131    1461    6187
# 1782   202302   10     814       3       0       0     135    1251    5713
# 3536   202303   10     861      23       0       0     151    1455    6623
# 5309   202304   10     979      12       0       0     203    1583    6673
# 7088   202305   10    1094      25       0       0     188    1671    7126
# 8876   202306   10     983      17       0       0     175    1809    7105
# 10664  202307   10    1023      28       0       0     189    1821    7064
# 12474  202308   10     816      12       0       0     175    1647    6253
# 14284  202309   10    1139      27       0       0     231    1784    7299
# 16109  202310   10    1141       2       0       0     212    1927    7366
# 17938  202311   10     957       6       0       0     217    1762    7342
# ...

# %%
df_gyeonggi_bus[(df_gyeonggi_bus['노선번호'] == '10') & (df_gyeonggi_bus['year'] == 202301)]
# Out:
#       year 노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  \
# 15  202301   10     898      21       0       0     131    1461    6187
#
#     07~08시  ...  15~16시  16~17시  17~18시  18~19시  19~20시  20~21시  21~22시  \
# 15   13398  ...   14032   15429   17548   19191   14657   11112    9935
#
#     22~23시  23~24시     승하차
# 15    8029    4243  230381
#
# [1 rows x 27 columns]

# %%
df_gyeonggi_bus.columns[2:-1]
# Out:
# Index(['00~01시', '01~02시', '02~03시', '03~04시', '04~05시', '05~06시', '06~07시',
#        '07~08시', '08~09시', '09~10시', '10~11시', '11~12시', '12~13시', '13~14시',
#        '14~15시', '15~16시', '16~17시', '17~18시', '18~19시', '19~20시', '20~21시',
#        '21~22시', '22~23시', '23~24시'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# '노선번호'가 '10'이고 'year'가 '202301'인 데이터 추출
df_selected_data = df_gyeonggi_bus[(df_gyeonggi_bus['노선번호'] == '10') & (df_gyeonggi_bus['year'] == 202301)]

# 시간대 및 해당 시간대의 승하차객수 데이터 추출
time_periods = df_selected_data.columns[2:-1]  # 시간대 컬럼 추출
passenger_counts = df_selected_data.iloc[0, 2:-1].astype(int)  # 승하차객수 데이터 추출

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.bar(time_periods, passenger_counts)
plt.title('10번 노선의 202301년 시간대별 승하차 인원')
plt.xlabel('시간대')
plt.ylabel('승하차 인원')
plt.xticks(rotation=45)  # x축 눈금 라벨 회전
plt.grid(axis='y')  # y축에만 그리드 표시
plt.tight_layout()
plt.show()

# %%
df_gyeonggi_bus.groupby('노선번호')[['승하차']].sum().sort_values('승하차', ascending = False)/14
# Out:
#                     승하차
# 노선번호
# 10        250696.357143
# 88        225056.928571
# 1         201077.000000
# 3         189025.857143
# 5         187537.214286
# ...                 ...
# 25-4           0.214286
# 09C            0.142857
# 62-2           0.142857
# 201보충대         0.142857
# 공영3(신경대)       0.142857
#
# [1932 rows x 1 columns]

# %%
df_gyeonggi_bus['승하차'].sum()/14
# Out:
# 14075268.57142857

# %%
df_seoul_bus['총승차인원'].sum() + df_seoul_bus['총하차인원'].sum()
# Out:
# 237303911.0

# %%
df_gyeonggi_bus3
# Out:
#        노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  07~08시  \
# 0         1       0       0       0       0       0      18     495     983
# 1         2       0       0       0       0       0       0       0      73
# 2         3     249       0       0       0       0     178     815       2
# 3         5     274       0       0       0      66     628     993       1
# 4         6       0       0       0       0       0      63     238     449
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2938   68-1       0       0       0       0       0       0       0       0
# 2939   70-1       0       0       0       0       0       0       0       0
# 2940   70-2       0       0       0       0       0       0       0       0
# 2941  38-10       0       0       0       0       0       0       0       0
# 2942  G2001      46      15       0       0       2      11      44      85
#
# ...

# %%
# 시간대별 승차 및 하차 컬럼 선택
time_columns = df_gyeonggi_bus3.columns[1:-1]  # 행정구역 컬럼과 주 컬럼을 제외한 시간대별 컬럼 선택

# 승하차 컬럼 추가
df_gyeonggi_bus3['승하차'] = df_gyeonggi_bus3[time_columns].sum(axis=1)  # 시간대별 승차 및 하차를 합산하여 "승하차" 컬럼 생성

# %%
df_gyeonggi_bus3
# Out:
#        노선번호  00~01시  01~02시  02~03시  03~04시  04~05시  05~06시  06~07시  07~08시  \
# 0         1       0       0       0       0       0      18     495     983
# 1         2       0       0       0       0       0       0       0      73
# 2         3     249       0       0       0       0     178     815    2121
# 3         5     274       0       0       0      66     628     993    1209
# 4         6       0       0       0       0       0      63     238     449
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2938   68-1       0       0       0       0       0       0       0       0
# 2939   70-1       0       0       0       0       0       0       0       0
# 2940   70-2       0       0       0       0       0       0       0       0
# 2941  38-10       0       0       0       0       0       0       0       0
# 2942  G2001      46      15       0       0       2      11      44      85
#
# ...

# %%
df_gyeonggi_bus3['승하차'].max()
# Out:
# 126797

# %%
df_gyeonggi_bus3['승하차'].sum()
# Out:
# 14097263

# %%
conn.close()

# %% [markdown]
# 경기도 버스노선 승하차 인원 한달 평균 14075268.57142857명 , 서울 버스노선 승하차 인원 한달 평균 237303911.0명, 인천 127983900.0

# %% [markdown]
# ---
# 인천

# %%
values = '0 0 0 0 0 248 705 1,046 1,530 1,338 868 1,091 1,317 1,351 1,502 1,344 1,512 1,504 1,752 1,160 898 778 448 83'

# 쉼표(,)를 제거하고 각 값을 정수형으로 변환하여 더하기
total_sum = sum(int(value.replace(',', '')) for value in values.split())

print("주어진 값들의 총 합:", total_sum)
# Out:
# 주어진 값들의 총 합: 20475

# %%
df_incheon_bus['일평균승하차건수'].sum() * 30
# Out:
# 127983900.0

# %%
df_incheon_bus
# Out:
#          ID          정류소명   정류소아이디    총승차건수    총하차건수  승차건수(카드)  하차건수(카드)  \
# 0         0    (구)국제여객터미널  35051.0     19.0   1169.0       9.0    1169.0
# 1         1    (구)국제여객터미널  35052.0   1554.0     20.0    1544.0      20.0
# 2         2    (구)시민회관사거리  37319.0   4794.0  44340.0    4767.0   44340.0
# 3         3    (구)시민회관사거리  37326.0  93402.0  18325.0   93294.0   18325.0
# 4         4     (주)경동세라믹스  89146.0    611.0     24.0     610.0      24.0
# ...     ...           ...      ...      ...      ...       ...       ...
# 19435  6458  힐스테이트학익104동앞  37670.0   2179.0   4804.0    2175.0    4804.0
# 19436  6459        힐캐슬프라자  39329.0  10659.0  15979.0   10624.0   15979.0
# 19437  6460        힐캐슬프라자  39331.0  16974.0   9229.0   16936.0    9229.0
# 19438  6461          힘찬병원  40891.0   5342.0   7579.0    5316.0    7579.0
# 19439  6462          힘찬병원  40892.0   3907.0   2680.0    3886.0    2680.0
#
#        승차건수(현금)  일평균승하차건수
# 0          10.0      38.0
# 1          10.0      50.0
# ...

# %%
df_traffic
# Out:
#         date start_si end_si      traffic   time  distance
# 0    2021-01      경기도    경기도   56833700.0  22.86    8410.0
# 1    2021-02      경기도    경기도   56473000.0  22.84    8451.0
# 2    2021-03      경기도    경기도   69859400.0  23.07    8522.0
# 3    2021-04      경기도    경기도   70945400.0  23.31    8602.0
# 4    2021-05      경기도    경기도   70438800.0  23.31    8578.0
# ..       ...      ...    ...          ...    ...       ...
# 235  2023-08    서울특별시  서울특별시  189704000.0  26.22    7970.0
# 236  2023-09    서울특별시  서울특별시  187951000.0  26.81    8050.0
# 237  2023-10    서울특별시  서울특별시  195060000.0  26.70    8144.0
# 238  2023-11    서울특별시  서울특별시  197725000.0  27.08    8164.0
# 239  2023-12    서울특별시  서울특별시  197478000.0  26.47    8017.0
#
# [240 rows x 6 columns]

# %%
seoul_gi = df_traffic[(df_traffic['start_si'] == '서울특별시') & (df_traffic['end_si'] == '경기도')]
gi_seoul = df_traffic[(df_traffic['start_si'] == '경기도') & (df_traffic['end_si'] == '서울특별시')]

seoul_inc = df_traffic[(df_traffic['start_si'] == '서울특별시') & (df_traffic['end_si'] == '인천광역시')]
inc_seoul = df_traffic[(df_traffic['start_si'] == '인천광역시') & (df_traffic['end_si'] == '서울특별시')]

seoul = df_traffic[(df_traffic['start_si'] == '서울특별시') & (df_traffic['end_si'] == '서울특별시')]
inc = df_traffic[(df_traffic['start_si'] == '인천광역시') & (df_traffic['end_si'] == '인천광역시')]

gi = df_traffic[(df_traffic['start_si'] == '경기도') & (df_traffic['end_si'] == '경기도')]

# %% [markdown]
# 경기에서 서울로 왕복하는 교통량(지하철, 버스)가 많은 것을 확인

# %%
import matplotlib.pyplot as plt

labels = ['Seoul_GI', 'GI_Seoul', 'Seoul_INC', 'INC_Seoul']
values = [seoul_gi['traffic'].sum(), gi_seoul['traffic'].sum(), seoul_inc['traffic'].sum(), inc_seoul['traffic'].sum()]

plt.figure(figsize=(8, 8))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('traffic Sum by Category')
plt.show()
